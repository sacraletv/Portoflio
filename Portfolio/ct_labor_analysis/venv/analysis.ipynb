# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("sqlite:///employment.db")
df = pd.read_sql("SELECT year, COUNT(*) as records FROM employment GROUP BY year", engine)

df.plot(x="year", y="records", kind="line", title="Employment Records by Year")
plt.show()
